# %% [markdown]
# <a href="https://colab.research.google.com/github/jihyeon602/pandas_test/blob/main/practices/sol_practice_pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # (실습) 데이터프레임 중심 프로그래밍

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **문제 1**

# %% [markdown]
# 아래의 딕셔너리 `data`를 이용하여 데이터프레임`df1`를 생성한다.

# %%
data = {'A' : [0, 5, 15, 20, 25, 30, 35, 40],
        'B' : [1, 2, 3, 4, 5, 6, 7, 8],
        'C' : [3, 3, 3, 3, 3, 3, 3, 3],
        'D' : [4, 2, 9, 1, 20, 3, 15, 17]}

df1 = pd.DataFrame(data)
df1
# Out:
#     A  B  C   D
# 0   0  1  3   4
# 1   5  2  3   2
# 2  15  3  3   9
# 3  20  4  3   1
# 4  25  5  3  20
# 5  30  6  3   3
# 6  35  7  3  15
# 7  40  8  3  17

# %% [markdown]
# (1) `df1`의 각 열의 합을 계산하는 한 줄 표현식을 작성하여라.

# %% [markdown]
# 답:

# %%
df1.sum(axis=0)
# Out:
# A    170
# B     36
# C     24
# D     71
# dtype: int64

# %% [markdown]
# (2) `df1`의 각 행의 합을 계산하는 한 줄 표현식을 작성하여라.

# %% [markdown]
# 답:

# %%
df1.sum(axis=1)
# Out:
# 0     8
# 1    12
# 2    30
# 3    28
# 4    53
# 5    42
# 6    60
# 7    68
# dtype: int64

# %% [markdown]
# **문제 2**

# %% [markdown]
# 아래 데이터프레임을 생성하기 위해 `pd.date_range()` 함수는 시간으로 구성된 인덱스 자료형을 생성한다.
# 함수 호출에 사용된 키워드 인자의 의미는 다음과 같다.
#
# - `start="20130101`: 2013년 1월 1일부터 시작
# - `periods=6`: 첫째 인자로 지정된 시간부터 6 개의 시간 데이터 샘플 생성
# - `freq="D"`: 시간 데이터 샘플을 일(day) 단위로 생성

# %%
dates = pd.date_range(start="20130101", periods=6, freq="D")
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.seed(0)

df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("CDAB"))
df
# Out:
#                    C         D         A         B
# 2013-01-01  1.764052  0.400157  0.978738  2.240893
# 2013-01-02  1.867558 -0.977278  0.950088 -0.151357
# 2013-01-03 -0.103219  0.410599  0.144044  1.454274
# 2013-01-04  0.761038  0.121675  0.443863  0.333674
# 2013-01-05  1.494079 -0.205158  0.313068 -0.854096
# 2013-01-06 -2.552990  0.653619  0.864436 -0.742165

# %% [markdown]
# (1) 열 라벨을 기준으로 오름차순으로 정렬된 데이터프레임을 생성하는 한 줄 표현식을 작성하여라.

# %% [markdown]
# 답:

# %%
df.sort_index(axis=1)
# Out:
#                    A         B         C         D
# 2013-01-01  0.978738  2.240893  1.764052  0.400157
# 2013-01-02  0.950088 -0.151357  1.867558 -0.977278
# 2013-01-03  0.144044  1.454274 -0.103219  0.410599
# 2013-01-04  0.443863  0.333674  0.761038  0.121675
# 2013-01-05  0.313068 -0.854096  1.494079 -0.205158
# 2013-01-06  0.864436 -0.742165 -2.552990  0.653619

# %% [markdown]
# (2) 열 라벨을 기준으로 내림차순으로 정렬된 데이터프레임을 생성하는 한 줄 표현식을 작성하여라.

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.400157  1.764052  2.240893  0.978738
# 2013-01-02 -0.977278  1.867558 -0.151357  0.950088
# 2013-01-03  0.410599 -0.103219  1.454274  0.144044
# 2013-01-04  0.121675  0.761038  0.333674  0.443863
# 2013-01-05 -0.205158  1.494079 -0.854096  0.313068
# 2013-01-06  0.653619 -2.552990 -0.742165  0.864436

# %% [markdown]
# (3) `B` 라벨 열의 항목을 기준으로 오름차순으로 정렬된 데이터프레임을 생성하는 한 줄 표현식을 작성하여라.

# %%
df.sort_values(by='B')
# Out:
#                    C         D         A         B
# 2013-01-05  1.494079 -0.205158  0.313068 -0.854096
# 2013-01-06 -2.552990  0.653619  0.864436 -0.742165
# 2013-01-02  1.867558 -0.977278  0.950088 -0.151357
# 2013-01-04  0.761038  0.121675  0.443863  0.333674
# 2013-01-03 -0.103219  0.410599  0.144044  1.454274
# 2013-01-01  1.764052  0.400157  0.978738  2.240893

# %% [markdown]
# ### 통계

# %%
df
# Out:
#                    C         D         A         B
# 2013-01-01  1.764052  0.400157  0.978738  2.240893
# 2013-01-02  1.867558 -0.977278  0.950088 -0.151357
# 2013-01-03 -0.103219  0.410599  0.144044  1.454274
# 2013-01-04  0.761038  0.121675  0.443863  0.333674
# 2013-01-05  1.494079 -0.205158  0.313068 -0.854096
# 2013-01-06 -2.552990  0.653619  0.864436 -0.742165

# %% [markdown]
# `F` 열은 결측치를 제외한 5개의 값의 평균값을 구한다.

# %%
df.mean()
# Out:
# C    0.538420
# D    0.067269
# A    0.615706
# B    0.380204
# dtype: float64

# %% [markdown]
# 결측치는 모든 연산에서 무시된다.
# 실제로 `F` 열에서 결측치를 제외한 항목 개수는 5이다.

# %%
df.F.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f1d60cb44748> in <cell line: 0>()
# ----> 1 df.F.value_counts()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'F'

# %%
df.F.value_counts().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-bd3ac02366b8> in <cell line: 0>()
# ----> 1 df.F.value_counts().sum()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'F'

# %% [markdown]
# 결측치를 제외한 항목의 합을 5로 나눈 값은 3.8이다.

# %%
df.F.sum()/5
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-0b73238a74f7> in <cell line: 0>()
# ----> 1 df.F.sum()/5
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'F'

# %% [markdown]
# 축을 지정하면 행 또는 열 기준으로 작동한다.

# %% [markdown]
# - 행별 평균값

# %%
df.mean(1) # axis=1
# Out:
# 2013-01-01    1.345960
# 2013-01-02    0.422253
# 2013-01-03    0.476424
# 2013-01-04    0.415063
# 2013-01-05    0.186973
# 2013-01-06   -0.444275
# Freq: D, dtype: float64

# %% [markdown]
# ### 사칙연산

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index = dates)
s
# Out:
# 2013-01-01    1.0
# 2013-01-02    3.0
# 2013-01-03    5.0
# 2013-01-04    NaN
# 2013-01-05    6.0
# 2013-01-06    8.0
# Freq: D, dtype: float64

# %% [markdown]
# 결측치를 더 추가한다.
#
# 참고; [`DataFrame.shift()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html)

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index = dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %% [markdown]
# - 행별 뺄셈: `df - s`

# %%
df
# Out:
#                    C         D         A         B
# 2013-01-01  1.764052  0.400157  0.978738  2.240893
# 2013-01-02  1.867558 -0.977278  0.950088 -0.151357
# 2013-01-03 -0.103219  0.410599  0.144044  1.454274
# 2013-01-04  0.761038  0.121675  0.443863  0.333674
# 2013-01-05  1.494079 -0.205158  0.313068 -0.854096
# 2013-01-06 -2.552990  0.653619  0.864436 -0.742165

# %% [markdown]
# 결측치가 관여하면 무조건 결측치로 처리된다.

# %%
df.sub(s, axis='index') # axis=0
# Out:
#                    C         D         A         B
# 2013-01-01       NaN       NaN       NaN       NaN
# 2013-01-02       NaN       NaN       NaN       NaN
# 2013-01-03 -1.103219 -0.589401 -0.855956  0.454274
# 2013-01-04 -2.238962 -2.878325 -2.556137 -2.666326
# 2013-01-05 -3.505921 -5.205158 -4.686932 -5.854096
# 2013-01-06       NaN       NaN       NaN       NaN

# %% [markdown]
# - 브로드캐스팅: 필요에 따라 자동 적용

# %%
df - 5
# Out:
#                    C         D         A         B
# 2013-01-01 -3.235948 -4.599843 -4.021262 -2.759107
# 2013-01-02 -3.132442 -5.977278 -4.049912 -5.151357
# 2013-01-03 -5.103219 -4.589401 -4.855956 -3.545726
# 2013-01-04 -4.238962 -4.878325 -4.556137 -4.666326
# 2013-01-05 -3.505921 -5.205158 -4.686932 -5.854096
# 2013-01-06 -7.552990 -4.346381 -4.135564 -5.742165

# %% [markdown]
# ### 함수 적용

# %% [markdown]
# - 참고: [`DataFrame.apply()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html#pandas.DataFrame.apply)

# %%
df
# Out:
#                    C         D         A         B
# 2013-01-01  1.764052  0.400157  0.978738  2.240893
# 2013-01-02  1.867558 -0.977278  0.950088 -0.151357
# 2013-01-03 -0.103219  0.410599  0.144044  1.454274
# 2013-01-04  0.761038  0.121675  0.443863  0.333674
# 2013-01-05  1.494079 -0.205158  0.313068 -0.854096
# 2013-01-06 -2.552990  0.653619  0.864436 -0.742165

# %% [markdown]
# - 열별 누적합

# %%
df.apply(np.cumsum)
# Out:
#                    C         D         A         B
# 2013-01-01  1.764052  0.400157  0.978738  2.240893
# 2013-01-02  3.631610 -0.577121  1.928826  2.089536
# 2013-01-03  3.528391 -0.166522  2.072870  3.543809
# 2013-01-04  4.289429 -0.044847  2.516733  3.877484
# 2013-01-05  5.783508 -0.250005  2.829801  3.023388
# 2013-01-06  3.230518  0.403613  3.694237  2.281223

# %% [markdown]
# - 행별 누적합

# %%
df.apply(np.cumsum, axis='columns') # axis=1
# Out:
#                    A         B          C          D          F
# 2013-01-01  0.000000  0.000000   0.262489   5.262489        NaN
# 2013-01-02  3.000000  6.000000   9.000000  12.000000  15.000000
# 2013-01-03  4.000000  8.000000  12.000000  16.000000  20.000000
# 2013-01-04  0.363123  0.204428   1.191890   6.191890   9.191890
# 2013-01-05  0.255047 -0.398036   0.089682   5.089682   9.089682
# 2013-01-06  0.016019 -1.261247  -3.173933   1.826067   6.826067

# %% [markdown]
# - 열별 최대값과 최소값의 차이. 결측치는 무시

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    4.000000
# B    5.277266
# C    5.912686
# D    2.000000
# F    2.000000
# dtype: float64

# %% [markdown]
# - 행별 최대값과 최소값의 차이. 결측치는 무시

# %%
df.apply(lambda x: x.max() - x.min(), axis=1)
# Out:
# 2013-01-01    5.000000
# 2013-01-02    0.000000
# 2013-01-03    0.000000
# 2013-01-04    5.158695
# 2013-01-05    5.653083
# 2013-01-06    6.912686
# Freq: D, dtype: float64
